# %%
# This notebook contains the code to differentiate images based on sports

# %%
# importing the libraries
import numpy as np

# for reading and displaying images
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# PyTorch libraries and modules
from torch.optim import lr_scheduler
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms
import torch

# %%
import wget
import time
import os
import copy

# %% [markdown]
# ## Loading the data

# %%
PATH = "/home/ubuntu/datasets/sports_images/"
sz=224

# %%
files = os.listdir(f'{PATH}train/baseball')[:5]
files
# Out:
# ['bs36.jpg', 'bs37.jpg', 'bs5.jpg', 'bs21.jpg', 'bs39.jpeg']

# %%
img = plt.imread(f'{PATH}train/baseball/{files[0]}')
plt.imshow(img);

# %%
img.shape
# Out:
# (2672, 3763, 3)

# %% [markdown]
# The numbers above mean the image has 2672*3763 pixels with 3 channels (R, G, and B).
# Lets verify it using img.size function

# %%
img.size
# Out:
# 30164208

# %%
2672*3763*3
# Out:
# 30164208

# %% [markdown]
# Let's have a look at what type of numbers are stored by selecting first 4 rows and columns.

# %%
img[:4,:4]
# Out:
# array([[[88, 74, 74],
#         [86, 72, 72],
#         [78, 64, 64],
#         [73, 59, 59]],
#
#        [[88, 74, 74],
#         [87, 73, 73],
#         [83, 69, 69],
#         [79, 65, 65]],
#
#        [[84, 70, 70],
#         [86, 72, 72],
#         [85, 71, 71],
#         [83, 69, 69]],
#
#        [[81, 67, 67],
#         [83, 69, 69],
#         [85, 71, 71],
#         [83, 69, 69]]], dtype=uint8)

# %% [markdown]
# ## Building a simple model

# %% [markdown]
# We're going to use a pre-trained model, that is, a model created by someone else to solve a different problem. Instead of building a model from scratch to solve a similar problem, we'll use a model trained on ImageNet (1.2 million images and 1000 classes) as a starting point. The model is a Convolutional Neural Network (CNN), a type of Neural Network that builds state-of-the-art models for computer vision.

# %% [markdown]
# ### Download pre-trained models

# %% [markdown]
# I used the following links to download the model
#
#     'resnet50': 'https://download.pytorch.org/models/resnet50-19c8e357.pth',
#     'resnet101': 'https://download.pytorch.org/models/resnet101-5d3b4d8f.pth',
#     'resnet152': 'https://download.pytorch.org/models/resnet152-b121ed2d.pth'

# %%
# url = "https://download.pytorch.org/models/resnet152-b121ed2d.pth"
# wget.download(url, '/home/ubuntu/pretrained_models/')

# %% [markdown]
# Lets check the size of each model

# %%
# !ls -l --block-size=M /home/ubuntu/pretrained_models/

# %% [markdown]
# As you can see above, when the number of number of layers double the pre-trained models also double in size.

# %% [markdown]
# If you wish to check all available pretrained models:

# %%
from torchvision import models
dir(models)
# Out:
# ['AlexNet',
#  'DenseNet',
#  'Inception3',
#  'ResNet',
#  'SqueezeNet',
#  'VGG',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'inception',
#  'inception_v3',
#  'resnet',
#  'resnet101',
#  'resnet152',
#  'resnet18',
#  'resnet34',
#  'resnet50',
#  'squeezenet',
#  'squeezenet1_0',
#  'squeezenet1_1',
#  'vgg',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# List of all transforms here:
#
# https://pytorch.org/docs/stable/torchvision/transforms.html

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
data_dir = '/home/ubuntu/datasets/sports_images/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}

# %%
dataloaders = {x: DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}

# %%
len(dataloaders), type(dataloaders)
# Out:
# (2, dict)

# %%
dataloaders.items()
# Out:
# dict_items([('train', <torch.utils.data.dataloader.DataLoader object at 0x7fa314444e80>), ('val', <torch.utils.data.dataloader.DataLoader object at 0x7fa3144445f8>)])

# %%
len(dataloaders['train']), len(dataloaders['val'])
# Out:
# (43, 20)

# %%
dataloaders['train'].dataset.imgs
# Out:
# [('/home/ubuntu/datasets/sports_images/train/baseball/bs1.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs10.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs11.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs12.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs13.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs14.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs15.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs16.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs17.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs18.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs19.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs2.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs20.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs21.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs22.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs23.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs24.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs25.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs26.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs27.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs28.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs29.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs3.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs30.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs31.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs32.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs33.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs34.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs35.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs36.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs37.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs38.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs39.jpeg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs4.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs5.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs6.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs7.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs8.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/baseball/bs9.jpg', 0),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/34.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb1.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb10.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb11.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb12.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb13.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb14.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb15.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb16.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb17.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb18.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb19.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb2.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb20.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb21.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb22.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb23.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb24.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb25.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb26.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb27.jpeg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb28.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb29.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb3.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb30.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb31.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb32.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb33.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb35.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb36.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb37.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb38.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb39.JPG', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb4.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb40.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb5.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb6.jpeg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb7.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb8.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/basketball/bb9.jpg', 1),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-24-31.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-24-52.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-25-26.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-38-17.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-38-40.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-39-13.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-40-01.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-42-38.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-44-26.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-46-34.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-47-03.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-47-19.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-48-35.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-48-45.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-49-23.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-49-32.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-49-55.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-52-02.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-52-46.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-53-20.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-53-55.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-54-34.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-56-06.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-56-34.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/Screenshot from 2020-01-15 18-57-03.png',
#   2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr1.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr10.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr11.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr12.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr13.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr14.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr15.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr16.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr17.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr18.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr19.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr2.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr20.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr21.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr22.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr23.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr24.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr25.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr3.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr4.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr5.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr6.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr7.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr8.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/cricket/cr9.jpg', 2),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc1.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc10.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc11.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc12.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc13.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc14.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc15.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc16.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc17.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc18.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc19.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc2.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc20.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc21.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc22.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc23.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc24.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc25.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc26.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc27.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc28.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc29.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc3.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc30.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc31.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc32.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc33.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc34.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc35.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc36.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc37.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc38.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc39.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc4.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc40.jpeg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc5.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc6.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc7.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc8.jpg', 3),
#  ('/home/ubuntu/datasets/sports_images/train/soccer/sc9.jpg', 3)]

# %%
dataloaders['val'].dataset.transform
# Out:
# Compose(
#     Resize(size=256, interpolation=PIL.Image.BILINEAR)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
class_names = image_datasets['train'].classes

# %%
class_names
# Out:
# ['baseball', 'basketball', 'cricket', 'soccer']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

# %%
dataset_sizes
# Out:
# {'train': 169, 'val': 78}

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
# Get a batch of training data as per the size of batch
inputs, classes = next(iter(dataloaders['train']))

# %%
classes
# Out:
# tensor([0, 1, 2, 3])

# %%
import torchvision

# %%
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

# %%
imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# #### Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=4):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# #### Finetuning the convnet

# %%
# Load a pretrained model and reset final fully connected layer.

model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 4.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 4)

# Ensuring the model is using GPU
model_ft = model_ft.to(device)

# As we have two classes (0 or 1) we will use cross-entropy as criterion
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# #### Train and evaluate

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.1537 Acc: 0.4793
# val Loss: 0.4071 Acc: 0.8077
#
# Epoch 1/24
# ----------
# train Loss: 0.6642 Acc: 0.7456
# val Loss: 0.2517 Acc: 0.8846
#
# Epoch 2/24
# ----------
# train Loss: 0.5914 Acc: 0.7751
# val Loss: 0.2824 Acc: 0.8846
#
# Epoch 3/24
# ----------
# train Loss: 0.5108 Acc: 0.8107
# val Loss: 0.2198 Acc: 0.8974
#
# Epoch 4/24
# ----------
# train Loss: 0.6651 Acc: 0.6982
# val Loss: 0.3158 Acc: 0.8590
#
# Epoch 5/24
# ----------
# train Loss: 0.4454 Acc: 0.8462
# val Loss: 0.2551 Acc: 0.8974
#
# Epoch 6/24
# ----------
# train Loss: 0.6385 Acc: 0.7929
# val Loss: 0.4088 Acc: 0.8590
#
# Epoch 7/24
# ----------
# train Loss: 0.5430 Acc: 0.8047
# val Loss: 0.5526 Acc: 0.8590
#
# Epoch 8/24
# ----------
# train Loss: 0.5304 Acc: 0.7929
# val Loss: 0.3561 Acc: 0.8974
#
# Epoch 9/24
# ----------
# train Loss: 0.3225 Acc: 0.8876
# val Loss: 0.2059 Acc: 0.9231
#
# Epoch 10/24
# ----------
# train Loss: 0.3201 Acc: 0.8757
# val Loss: 0.2040 Acc: 0.9231
#
# Epoch 11/24
# ----------
# train Loss: 0.3221 Acc: 0.8757
# val Loss: 0.1721 Acc: 0.9487
#
# Epoch 12/24
# ----------
# train Loss: 0.3547 Acc: 0.8639
# val Loss: 0.1654 Acc: 0.9359
#
# Epoch 13/24
# ----------
# train Loss: 0.3693 Acc: 0.8698
# val Loss: 0.1862 Acc: 0.8974
#
# Epoch 14/24
# ----------
# train Loss: 0.2770 Acc: 0.8876
# val Loss: 0.1485 Acc: 0.9359
#
# Epoch 15/24
# ----------
# train Loss: 0.3026 Acc: 0.8876
# val Loss: 0.1614 Acc: 0.9231
#
# Epoch 16/24
# ----------
# train Loss: 0.3093 Acc: 0.9112
# val Loss: 0.1823 Acc: 0.9231
#
# Epoch 17/24
# ----------
# train Loss: 0.2892 Acc: 0.9112
# val Loss: 0.2302 Acc: 0.9103
#
# Epoch 18/24
# ----------
# train Loss: 0.2471 Acc: 0.9231
# val Loss: 0.1741 Acc: 0.9359
#
# Epoch 19/24
# ----------
# train Loss: 0.2877 Acc: 0.8757
# val Loss: 0.1472 Acc: 0.9359
#
# Epoch 20/24
# ----------
# train Loss: 0.3376 Acc: 0.8757
# val Loss: 0.1409 Acc: 0.9615
#
# Epoch 21/24
# ----------
# train Loss: 0.3563 Acc: 0.8639
# val Loss: 0.1349 Acc: 0.9487
#
# Epoch 22/24
# ----------
# train Loss: 0.2611 Acc: 0.9053
# val Loss: 0.1769 Acc: 0.9103
#
# Epoch 23/24
# ----------
# train Loss: 0.3006 Acc: 0.8817
# val Loss: 0.2320 Acc: 0.9103
#
# Epoch 24/24
# ----------
# train Loss: 0.3780 Acc: 0.8580
# val Loss: 0.1416 Acc: 0.9487
#
# Training complete in 1m 1s
# Best val Acc: 0.961538

# %%
visualize_model(model_ft)

# %% [markdown]
# Let's try a more complex models than ResNet18.

# %%
model_ft = models.resnet50(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 4)

# Ensuring the model is using GPU
model_ft = model_ft.to(device)

# As we have two classes (0 or 1) we will use cross-entropy as criterion
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.2951 Acc: 0.3787
# val Loss: 0.5508 Acc: 0.7692
#
# Epoch 1/24
# ----------
# train Loss: 0.7100 Acc: 0.7396
# val Loss: 0.1965 Acc: 0.9231
#
# Epoch 2/24
# ----------
# train Loss: 0.7072 Acc: 0.7337
# val Loss: 0.1793 Acc: 0.9231
#
# Epoch 3/24
# ----------
# train Loss: 0.6227 Acc: 0.7574
# val Loss: 0.1267 Acc: 0.9615
#
# Epoch 4/24
# ----------
# train Loss: 0.5421 Acc: 0.7988
# val Loss: 0.2095 Acc: 0.9359
#
# Epoch 5/24
# ----------
# train Loss: 0.5895 Acc: 0.8047
# val Loss: 0.3231 Acc: 0.8974
#
# Epoch 6/24
# ----------
# train Loss: 0.5924 Acc: 0.7692
# val Loss: 0.1935 Acc: 0.8846
#
# Epoch 7/24
# ----------
# train Loss: 0.8114 Acc: 0.7278
# val Loss: 0.1798 Acc: 0.9231
#
# Epoch 8/24
# ----------
# train Loss: 0.4886 Acc: 0.8166
# val Loss: 0.1539 Acc: 0.9231
#
# Epoch 9/24
# ----------
# train Loss: 0.3576 Acc: 0.8698
# val Loss: 0.1969 Acc: 0.9103
#
# Epoch 10/24
# ----------
# train Loss: 0.2636 Acc: 0.9053
# val Loss: 0.1322 Acc: 0.9487
#
# Epoch 11/24
# ----------
# train Loss: 0.3345 Acc: 0.8580
# val Loss: 0.1692 Acc: 0.9359
#
# Epoch 12/24
# ----------
# train Loss: 0.3834 Acc: 0.8580
# val Loss: 0.1332 Acc: 0.9359
#
# Epoch 13/24
# ----------
# train Loss: 0.3258 Acc: 0.8935
# val Loss: 0.1150 Acc: 0.9487
#
# Epoch 14/24
# ----------
# train Loss: 0.3241 Acc: 0.8876
# val Loss: 0.1286 Acc: 0.9615
#
# Epoch 15/24
# ----------
# train Loss: 0.3475 Acc: 0.9053
# val Loss: 0.1211 Acc: 0.9487
#
# Epoch 16/24
# ----------
# train Loss: 0.2664 Acc: 0.8817
# val Loss: 0.1254 Acc: 0.9487
#
# Epoch 17/24
# ----------
# train Loss: 0.3393 Acc: 0.8935
# val Loss: 0.1316 Acc: 0.9359
#
# Epoch 18/24
# ----------
# train Loss: 0.2104 Acc: 0.9172
# val Loss: 0.1255 Acc: 0.9487
#
# Epoch 19/24
# ----------
# train Loss: 0.2050 Acc: 0.9172
# val Loss: 0.1366 Acc: 0.9487
#
# Epoch 20/24
# ----------
# train Loss: 0.2245 Acc: 0.9290
# val Loss: 0.1391 Acc: 0.9359
#
# Epoch 21/24
# ----------
# train Loss: 0.2476 Acc: 0.9290
# val Loss: 0.1451 Acc: 0.9231
#
# Epoch 22/24
# ----------
# train Loss: 0.3003 Acc: 0.8817
# val Loss: 0.1270 Acc: 0.9487
#
# Epoch 23/24
# ----------
# train Loss: 0.1923 Acc: 0.9467
# val Loss: 0.1460 Acc: 0.9487
#
# Epoch 24/24
# ----------
# train Loss: 0.1692 Acc: 0.9527
# val Loss: 0.1278 Acc: 0.9487
#
# Training complete in 1m 8s
# Best val Acc: 0.961538

# %%
model_ft = models.resnet101(pretrained=True)
num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 4)

# Ensuring the model is using GPU
model_ft = model_ft.to(device)

# As we have two classes (0 or 1) we will use cross-entropy as criterion
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /home/ubuntu/.torch/models/resnet101-5d3b4d8f.pth
# 178728960it [00:14, 12528409.84it/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.2666 Acc: 0.4379
# val Loss: 0.3254 Acc: 0.9359
#
# Epoch 1/24
# ----------
# train Loss: 0.5862 Acc: 0.7692
# val Loss: 0.1763 Acc: 0.9487
#
# Epoch 2/24
# ----------
# train Loss: 0.4318 Acc: 0.8284
# val Loss: 0.1340 Acc: 0.9359
#
# Epoch 3/24
# ----------
# train Loss: 0.5180 Acc: 0.8166
# val Loss: 0.1521 Acc: 0.9359
#
# Epoch 4/24
# ----------
# train Loss: 0.4344 Acc: 0.8698
# val Loss: 0.3209 Acc: 0.8718
#
# Epoch 5/24
# ----------
# train Loss: 0.5989 Acc: 0.7811
# val Loss: 0.3825 Acc: 0.8205
#
# Epoch 6/24
# ----------
# train Loss: 0.3688 Acc: 0.8402
# val Loss: 0.1853 Acc: 0.9615
#
# Epoch 7/24
# ----------
# train Loss: 0.5664 Acc: 0.7988
# val Loss: 0.3770 Acc: 0.8846
#
# Epoch 8/24
# ----------
# train Loss: 0.3177 Acc: 0.8817
# val Loss: 0.1940 Acc: 0.9231
#
# Epoch 9/24
# ----------
# train Loss: 0.3294 Acc: 0.8935
# val Loss: 0.2022 Acc: 0.9103
#
# Epoch 10/24
# ----------
# train Loss: 0.2864 Acc: 0.9053
# val Loss: 0.1388 Acc: 0.9487
#
# Epoch 11/24
# ----------
# train Loss: 0.3666 Acc: 0.8639
# val Loss: 0.2832 Acc: 0.8974
#
# Epoch 12/24
# ----------
# train Loss: 0.2427 Acc: 0.9053
# val Loss: 0.2191 Acc: 0.9103
#
# Epoch 13/24
# ----------
# train Loss: 0.3120 Acc: 0.9053
# val Loss: 0.1440 Acc: 0.9615
#
# Epoch 14/24
# ----------
# train Loss: 0.1758 Acc: 0.9586
# val Loss: 0.1494 Acc: 0.9487
#
# Epoch 15/24
# ----------
# train Loss: 0.1782 Acc: 0.9467
# val Loss: 0.1835 Acc: 0.9103
#
# Epoch 16/24
# ----------
# train Loss: 0.2170 Acc: 0.9172
# val Loss: 0.1662 Acc: 0.9359
#
# Epoch 17/24
# ----------
# train Loss: 0.2947 Acc: 0.8935
# val Loss: 0.1747 Acc: 0.9359
#
# Epoch 18/24
# ----------
# train Loss: 0.1634 Acc: 0.9349
# val Loss: 0.1294 Acc: 0.9744
#
# Epoch 19/24
# ----------
# train Loss: 0.2498 Acc: 0.9053
# val Loss: 0.1500 Acc: 0.9615
#
# Epoch 20/24
# ----------
# train Loss: 0.3238 Acc: 0.8757
# val Loss: 0.1251 Acc: 0.9615
#
# Epoch 21/24
# ----------
# train Loss: 0.2712 Acc: 0.9112
# val Loss: 0.1492 Acc: 0.9359
#
# Epoch 22/24
# ----------
# train Loss: 0.2339 Acc: 0.9112
# val Loss: 0.1402 Acc: 0.9487
#
# Epoch 23/24
# ----------
# train Loss: 0.2813 Acc: 0.9053
# val Loss: 0.1735 Acc: 0.9359
#
# Epoch 24/24
# ----------
# train Loss: 0.2147 Acc: 0.9290
# val Loss: 0.1413 Acc: 0.9487
#
# Training complete in 1m 31s
# Best val Acc: 0.974359

# %% [markdown]
# It seems using more complex model did give us a little better accuracy.
